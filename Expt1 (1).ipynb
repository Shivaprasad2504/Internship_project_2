# %%
##Step1 : Import library
import pandas as pd

# %%
##Step2 : import data
salary = pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Salary%20Data.csv")
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Experience Years', y='Salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
_df_5['Experience Years'].plot(kind='line', figsize=(8, 4), title='Experience Years')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
from matplotlib import pyplot as plt
_df_8['Salary'].plot(kind='hist', bins=20, title='Salary')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_11['Salary'].plot(kind='line', figsize=(8, 4), title='Salary')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
salary.shape
# Out:
# (40, 2)

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
salary
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
## Step3 : Define target(y) and feature(x)

y = salary['Salary']
x = salary[['Experience Years']]

# %%
y.shape
# Out:
# (40,)

# %%
x.shape
# Out:
# (40, 1)

# %%
## Step4 : Test-Train split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =  train_test_split(x,y,train_size = 0.8)

# %%
x_train
y_train
# Out:
# 18     59095
# 34    109431
# 15     55794
# 27     91000
# 29     91738
# 19     61111
# 20     64500
# 36    116969
# 14     63218
# 13     60200
# 6      48266
# 24     82200
# 12     57189
# 39    121872
# 4      43525
# 38    122391
# 11     60000
# 35    105582
# 28     90000
# 22     66029
# 31    101302
# 1      42774
# 23     83088
# 33    111620
# 2      46205
# 9      54445
# 5      39891
# 32    113812
# 26     93940
# 17     57081
# 3      37731
# 8      60150
# Name: Salary, dtype: int64

# %%
x_train,x_test,y_train,y_test =  train_test_split(x,y,train_size = 0.7,random_state=2526)

# %%
x_train
# Out:
#     Experience Years
# 33               8.5
# 2                1.3
# 11               3.5
# 39              10.5
# 23               5.3
# 15               4.0
# 8                3.0
# 3                1.5
# 7                2.9
# 34               8.7
# 16               4.0
# 6                2.5
# 32               8.2
# 38              10.3
# 35               9.0
# 18               4.3
# 14               3.9
# 28               6.5
# 27               6.2
# 10               3.2
# 20               4.7
# 9                3.2
# 4                2.0
# 30               7.1
# 0                1.1
# 29               6.8
# 26               6.0
# 37               9.6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_train['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
x_train['Experience Years'].plot(kind='line', figsize=(8, 4), title='Experience Years')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
## Step5: Select the model form the scklearn library
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
## Step6: Train the model(Fit mode).
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 27414.714923739477

# %%
model.coef_
# Out:
# array([9391.6507587])

# %%
## Step7: Prediction
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 75312.13379309, 101608.75591744,  62163.82273092,  48076.34659287,
#         79068.79409657,  63102.98780678,  69677.14333787, 116635.39713135,
#         65920.48303439,  82825.45440005,  73433.80364135,  38684.69583417])

# %%
x_test
# Out:
#     Experience Years
# 22               5.1
# 31               7.9
# 12               3.7
# 5                2.2
# 24               5.5
# 13               3.8
# 19               4.5
# 36               9.5
# 17               4.1
# 25               5.9
# 21               4.9
# 1                1.2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_test['Experience Years'].plot(kind='hist', bins=20, title='Experience Years')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x_test['Experience Years'].plot(kind='line', figsize=(8, 4), title='Experience Years')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
## Step8 : Accuracy
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
E=mean_absolute_percentage_error(y_test,y_pred)

# %%
100-E
# Out:
# 99.91546063735638
